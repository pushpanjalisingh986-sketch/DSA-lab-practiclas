# %%
my_list = ["Ashpreet", "vijaya", "Aashi", "Samiksha" , "Pushpanjali", "Shubham" ,  "Amaan"]

# Print element with its position
for position, element in enumerate(my_list):
    print("Position:", position, "Element:", element,  "Address:", id(element))
# Out:
# Position: 0 Element: Ashpreet Address: 2568510104880
# Position: 1 Element: vijaya Address: 2568509771808
# Position: 2 Element: Aashi Address: 2568509771568
# Position: 3 Element: Samiksha Address: 2568510103216
# Position: 4 Element: Pushpanjali Address: 2568510098160
# Position: 5 Element: Shubham Address: 2568509777472
# Position: 6 Element: Amaan Address: 2568509772384

# %%
from array import array
a=array('i',[4,6,8,9,2,5])
print("Element   Position")
for i in range(0,len(a)):
    print(f"Index {i} -> Address {a.buffer_info()[0] + i * a.itemsize}")
# Out:
# Element   Position
# Index 0 -> Address 2568509333136
# Index 1 -> Address 2568509333140
# Index 2 -> Address 2568509333144
# Index 3 -> Address 2568509333148
# Index 4 -> Address 2568509333152
# Index 5 -> Address 2568509333156

# %%
a=[23,45,65,87,98,99]
for i in range(0,len(a)):
    print(a[i],"-", i)
# Out:
# 23 - 0
# 45 - 1
# 65 - 2
# 87 - 3
# 98 - 4
# 99 - 5

# %%
a=[23,45,65,98,99]
for i in range(0,len(a)):
    if a[i]==98:
        print(i)
# Out:
# 3

# %%
a=[24,45,76,99,132,87]
print(a[4])
# Out:
# 132
